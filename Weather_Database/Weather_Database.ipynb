# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 774

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
print(weather_api_key)
# Out:
# 6743ed5b0f5ab444b9bb6abe3748e540

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6743ed5b0f5ab444b9bb6abe3748e540

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1    

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
       
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
    
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description" : city_description,
                         
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 3 of Set 1 | arraial do cabo
# Processing Record 4 of Set 1 | ordzhonikidze
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | zhanaozen
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | san cristobal
# Processing Record 11 of Set 1 | fortuna
# Processing Record 12 of Set 1 | santa comba
# Processing Record 13 of Set 1 | ciudad bolivar
# Processing Record 14 of Set 1 | filadelfia
# Processing Record 15 of Set 1 | saint-pierre
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | ribeira grande
# Processing Record 19 of Set 1 | plavinas
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | byron bay
# Processing Record 22 of Set 1 | lorengau
# Processing Record 23 of Set 1 | carnarvon
# Processing Record 24 of Set 1 | matara
# Processing Record 25 of Set 1 | qaanaaq
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | berdigestyakh
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | general roca
# Processing Record 31 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 32 of Set 1 | black river
# Processing Record 33 of Set 1 | inhambane
# Processing Record 34 of Set 1 | cherskiy
# Processing Record 35 of Set 1 | ayan
# Processing Record 36 of Set 1 | kluczbork
# Processing Record 37 of Set 1 | lamu
# Processing Record 38 of Set 1 | lhokseumawe
# Processing Record 39 of Set 1 | chicama
# Processing Record 40 of Set 1 | bandarbeyla
# Processing Record 41 of Set 1 | marienburg
# Processing Record 42 of Set 1 | altamont
# Processing Record 43 of Set 1 | los llanos de aridane
# Processing Record 44 of Set 1 | bria
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | fianga
# City not found. Skipping...
# Processing Record 47 of Set 1 | tasiilaq
# Processing Record 48 of Set 1 | ullapool
# Processing Record 49 of Set 1 | ponta do sol
# Processing Record 50 of Set 1 | andenes
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | piacabucu
# Processing Record 3 of Set 2 | husavik
# Processing Record 4 of Set 2 | madinat sittah uktubar
# Processing Record 5 of Set 2 | saskylakh
# Processing Record 6 of Set 2 | kruisfontein
# Processing Record 7 of Set 2 | katherine
# Processing Record 8 of Set 2 | dingle
# Processing Record 9 of Set 2 | inta
# Processing Record 10 of Set 2 | bad tolz
# Processing Record 11 of Set 2 | avera
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | chokurdakh
# Processing Record 14 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 2 | kargil
# Processing Record 16 of Set 2 | padang
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | bubaque
# Processing Record 19 of Set 2 | rakitnoye
# Processing Record 20 of Set 2 | dakar
# Processing Record 21 of Set 2 | geraldton
# Processing Record 22 of Set 2 | maloshuyka
# City not found. Skipping...
# Processing Record 23 of Set 2 | moshi
# Processing Record 24 of Set 2 | saint anthony
# Processing Record 25 of Set 2 | shu
# Processing Record 26 of Set 2 | mar del plata
# Processing Record 27 of Set 2 | cabo san lucas
# Processing Record 28 of Set 2 | castro
# Processing Record 29 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 2 | alyangula
# Processing Record 31 of Set 2 | sanok
# Processing Record 32 of Set 2 | namtsy
# Processing Record 33 of Set 2 | hobart
# Processing Record 34 of Set 2 | tautira
# Processing Record 35 of Set 2 | tura
# Processing Record 36 of Set 2 | port elizabeth
# Processing Record 37 of Set 2 | albany
# Processing Record 38 of Set 2 | baraboo
# Processing Record 39 of Set 2 | sorland
# Processing Record 40 of Set 2 | bambous virieux
# Processing Record 41 of Set 2 | saint-augustin
# Processing Record 42 of Set 2 | bengkulu
# Processing Record 43 of Set 2 | thompson
# Processing Record 44 of Set 2 | ishigaki
# Processing Record 45 of Set 2 | upernavik
# Processing Record 46 of Set 2 | tongzi
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | talnakh
# Processing Record 49 of Set 2 | taoudenni
# Processing Record 50 of Set 2 | chapais
# Processing Record 1 of Set 3 | long branch
# Processing Record 2 of Set 3 | riyadh
# Processing Record 3 of Set 3 | pacific grove
# Processing Record 4 of Set 3 | vao
# Processing Record 5 of Set 3 | bambanglipuro
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | naze
# Processing Record 8 of Set 3 | kalmunai
# Processing Record 9 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 3 | cidreira
# Processing Record 11 of Set 3 | hambantota
# Processing Record 12 of Set 3 | new braunfels
# Processing Record 13 of Set 3 | porbandar
# Processing Record 14 of Set 3 | marystown
# Processing Record 15 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 3 | atuona
# Processing Record 17 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 3 | georgetown
# Processing Record 19 of Set 3 | berlevag
# Processing Record 20 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 21 of Set 3 | muros
# Processing Record 22 of Set 3 | aswan
# Processing Record 23 of Set 3 | dikson
# Processing Record 24 of Set 3 | bundaberg
# Processing Record 25 of Set 3 | aykhal
# Processing Record 26 of Set 3 | tsentralnyy
# City not found. Skipping...
# Processing Record 27 of Set 3 | iqaluit
# Processing Record 28 of Set 3 | olafsvik
# Processing Record 29 of Set 3 | belomorsk
# Processing Record 30 of Set 3 | wucheng
# Processing Record 31 of Set 3 | ahipara
# Processing Record 32 of Set 3 | saint-philippe
# Processing Record 33 of Set 3 | mbour
# Processing Record 34 of Set 3 | narsaq
# Processing Record 35 of Set 3 | faanui
# Processing Record 36 of Set 3 | east london
# Processing Record 37 of Set 3 | baghdad
# Processing Record 38 of Set 3 | barra dos coqueiros
# Processing Record 39 of Set 3 | usinsk
# Processing Record 40 of Set 3 | pandan
# Processing Record 41 of Set 3 | rocha
# Processing Record 42 of Set 3 | bonavista
# Processing Record 43 of Set 3 | piet retief
# Processing Record 44 of Set 3 | ust-omchug
# Processing Record 45 of Set 3 | acapulco
# Processing Record 46 of Set 3 | puerto ayora
# Processing Record 47 of Set 3 | adre
# Processing Record 48 of Set 3 | severo-kurilsk
# Processing Record 49 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 3 | asau
# Processing Record 1 of Set 4 | pangkalanbuun
# Processing Record 2 of Set 4 | ilulissat
# Processing Record 3 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 4 | barrow
# Processing Record 5 of Set 4 | ippy
# Processing Record 6 of Set 4 | shchelyayur
# City not found. Skipping...
# Processing Record 7 of Set 4 | issenye
# Processing Record 8 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 4 | ancud
# Processing Record 10 of Set 4 | walvis bay
# Processing Record 11 of Set 4 | omboue
# Processing Record 12 of Set 4 | alofi
# Processing Record 13 of Set 4 | turan
# Processing Record 14 of Set 4 | vulcan
# Processing Record 15 of Set 4 | fort nelson
# Processing Record 16 of Set 4 | takoradi
# Processing Record 17 of Set 4 | airai
# Processing Record 18 of Set 4 | coruripe
# Processing Record 19 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 4 | provideniya
# Processing Record 21 of Set 4 | ostrovnoy
# Processing Record 22 of Set 4 | edea
# Processing Record 23 of Set 4 | acari
# Processing Record 24 of Set 4 | bukachacha
# Processing Record 25 of Set 4 | lakatoro
# Processing Record 26 of Set 4 | gusau
# Processing Record 27 of Set 4 | butaritari
# Processing Record 28 of Set 4 | yellowknife
# Processing Record 29 of Set 4 | dukat
# Processing Record 30 of Set 4 | isla vista
# Processing Record 31 of Set 4 | norman wells
# Processing Record 32 of Set 4 | robertsport
# Processing Record 33 of Set 4 | jatiroto
# Processing Record 34 of Set 4 | madimba
# Processing Record 35 of Set 4 | kodiak
# Processing Record 36 of Set 4 | necochea
# Processing Record 37 of Set 4 | severnyy
# Processing Record 38 of Set 4 | bodden town
# Processing Record 39 of Set 4 | bajil
# Processing Record 40 of Set 4 | hofn
# Processing Record 41 of Set 4 | ratnagiri
# Processing Record 42 of Set 4 | yilan
# Processing Record 43 of Set 4 | new norfolk
# Processing Record 44 of Set 4 | sao filipe
# Processing Record 45 of Set 4 | sitka
# Processing Record 46 of Set 4 | milkovo
# Processing Record 47 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 4 | shelburne
# Processing Record 49 of Set 4 | haines junction
# Processing Record 50 of Set 4 | ichchapuram
# Processing Record 1 of Set 5 | fare
# Processing Record 2 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 5 | isangel
# Processing Record 4 of Set 5 | pangai
# Processing Record 5 of Set 5 | amapa
# Processing Record 6 of Set 5 | felidhoo
# City not found. Skipping...
# Processing Record 7 of Set 5 | pizhanka
# Processing Record 8 of Set 5 | constitucion
# Processing Record 9 of Set 5 | kostino
# Processing Record 10 of Set 5 | pilao arcado
# City not found. Skipping...
# Processing Record 11 of Set 5 | avarua
# Processing Record 12 of Set 5 | severo-yeniseyskiy
# Processing Record 13 of Set 5 | santa fe
# Processing Record 14 of Set 5 | laibin
# Processing Record 15 of Set 5 | sonoita
# Processing Record 16 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 17 of Set 5 | tahta
# Processing Record 18 of Set 5 | pimenta bueno
# Processing Record 19 of Set 5 | vardo
# Processing Record 20 of Set 5 | khatanga
# Processing Record 21 of Set 5 | oranjemund
# Processing Record 22 of Set 5 | bantogon
# Processing Record 23 of Set 5 | yulara
# Processing Record 24 of Set 5 | oistins
# Processing Record 25 of Set 5 | uarini
# Processing Record 26 of Set 5 | mahebourg
# Processing Record 27 of Set 5 | nouakchott
# Processing Record 28 of Set 5 | banugao
# Processing Record 29 of Set 5 | progreso
# Processing Record 30 of Set 5 | caravelas
# Processing Record 31 of Set 5 | jadu
# Processing Record 32 of Set 5 | tiksi
# Processing Record 33 of Set 5 | shimoda
# Processing Record 34 of Set 5 | lebu
# Processing Record 35 of Set 5 | nanortalik
# Processing Record 36 of Set 5 | dzhebariki-khaya
# Processing Record 37 of Set 5 | sibu
# Processing Record 38 of Set 5 | kununurra
# Processing Record 39 of Set 5 | cahors
# Processing Record 40 of Set 5 | edson
# Processing Record 41 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 42 of Set 5 | hobyo
# Processing Record 43 of Set 5 | zyryanka
# Processing Record 44 of Set 5 | novobirilyussy
# Processing Record 45 of Set 5 | lanigan
# Processing Record 46 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 47 of Set 5 | inzer
# Processing Record 48 of Set 5 | krasnovishersk
# Processing Record 49 of Set 5 | balykshi
# Processing Record 50 of Set 5 | mpulungu
# Processing Record 1 of Set 6 | hithadhoo
# Processing Record 2 of Set 6 | kavaratti
# Processing Record 3 of Set 6 | magadan
# Processing Record 4 of Set 6 | port lincoln
# Processing Record 5 of Set 6 | karratha
# Processing Record 6 of Set 6 | madang
# Processing Record 7 of Set 6 | mackay
# Processing Record 8 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 6 | deputatskiy
# Processing Record 10 of Set 6 | tupiza
# Processing Record 11 of Set 6 | koslan
# Processing Record 12 of Set 6 | aasiaat
# Processing Record 13 of Set 6 | oussouye
# Processing Record 14 of Set 6 | eyl
# Processing Record 15 of Set 6 | ca mau
# Processing Record 16 of Set 6 | manta
# Processing Record 17 of Set 6 | cairns
# Processing Record 18 of Set 6 | daraitan
# Processing Record 19 of Set 6 | hamilton
# Processing Record 20 of Set 6 | sola
# Processing Record 21 of Set 6 | sheridan
# Processing Record 22 of Set 6 | hvolsvollur
# Processing Record 23 of Set 6 | fairbanks
# Processing Record 24 of Set 6 | leningradskiy
# Processing Record 25 of Set 6 | yialos
# City not found. Skipping...
# Processing Record 26 of Set 6 | ustka
# Processing Record 27 of Set 6 | christchurch
# Processing Record 28 of Set 6 | salinopolis
# Processing Record 29 of Set 6 | kahului
# Processing Record 30 of Set 6 | purna
# Processing Record 31 of Set 6 | sarangani
# Processing Record 32 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 6 | zhoucheng
# Processing Record 34 of Set 6 | tenenkou
# Processing Record 35 of Set 6 | storslett
# Processing Record 36 of Set 6 | diamantino
# Processing Record 37 of Set 6 | dmitriyevskaya
# Processing Record 38 of Set 6 | marsh harbour
# Processing Record 39 of Set 6 | witu
# Processing Record 40 of Set 6 | mitsamiouli
# Processing Record 41 of Set 6 | nuuk
# Processing Record 42 of Set 6 | beringovskiy
# Processing Record 43 of Set 6 | gigmoto
# Processing Record 44 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 6 | saldanha
# Processing Record 46 of Set 6 | onguday
# Processing Record 47 of Set 6 | tabou
# Processing Record 48 of Set 6 | krasnogorsk
# Processing Record 49 of Set 6 | likasi
# Processing Record 50 of Set 6 | esna
# Processing Record 1 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 7 | katsuura
# Processing Record 3 of Set 7 | ballina
# Processing Record 4 of Set 7 | povorino
# Processing Record 5 of Set 7 | maralal
# Processing Record 6 of Set 7 | kars
# Processing Record 7 of Set 7 | praia da vitoria
# Processing Record 8 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 7 | bida
# Processing Record 10 of Set 7 | wonopringgo
# Processing Record 11 of Set 7 | bilibino
# Processing Record 12 of Set 7 | zonguldak
# Processing Record 13 of Set 7 | kaitangata
# Processing Record 14 of Set 7 | guerrero negro
# Processing Record 15 of Set 7 | nikolskoye
# Processing Record 16 of Set 7 | finschhafen
# Processing Record 17 of Set 7 | port hardy
# Processing Record 18 of Set 7 | mamou
# Processing Record 19 of Set 7 | port hedland
# Processing Record 20 of Set 7 | miandrivazo
# Processing Record 21 of Set 7 | zhigansk
# Processing Record 22 of Set 7 | huarmey
# Processing Record 23 of Set 7 | viana
# Processing Record 24 of Set 7 | siedlce
# Processing Record 25 of Set 7 | kutum
# Processing Record 26 of Set 7 | puerto narino
# Processing Record 27 of Set 7 | ambon
# Processing Record 28 of Set 7 | souillac
# Processing Record 29 of Set 7 | quatre cocos
# Processing Record 30 of Set 7 | dunedin
# Processing Record 31 of Set 7 | storforshei
# Processing Record 32 of Set 7 | paamiut
# Processing Record 33 of Set 7 | nouadhibou
# Processing Record 34 of Set 7 | gat
# Processing Record 35 of Set 7 | zouxian
# City not found. Skipping...
# Processing Record 36 of Set 7 | vostok
# Processing Record 37 of Set 7 | jiuquan
# Processing Record 38 of Set 7 | buala
# Processing Record 39 of Set 7 | real
# Processing Record 40 of Set 7 | umea
# Processing Record 41 of Set 7 | kaoma
# Processing Record 42 of Set 7 | saint-francois
# Processing Record 43 of Set 7 | dunmore east
# Processing Record 44 of Set 7 | maniitsoq
# Processing Record 45 of Set 7 | la rioja
# Processing Record 46 of Set 7 | gazojak
# Processing Record 47 of Set 7 | chuy
# Processing Record 48 of Set 7 | yatsuo
# Processing Record 49 of Set 7 | rio bueno
# Processing Record 50 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 8 | daru
# Processing Record 2 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 3 of Set 8 | tanshui
# City not found. Skipping...
# Processing Record 4 of Set 8 | aitape
# Processing Record 5 of Set 8 | saint george
# Processing Record 6 of Set 8 | margate
# Processing Record 7 of Set 8 | mantua
# Processing Record 8 of Set 8 | wahiawa
# Processing Record 9 of Set 8 | falaleu
# City not found. Skipping...
# Processing Record 10 of Set 8 | brigantine
# Processing Record 11 of Set 8 | opuwo
# Processing Record 12 of Set 8 | pochutla
# Processing Record 13 of Set 8 | amga
# Processing Record 14 of Set 8 | siderno
# Processing Record 15 of Set 8 | nurota
# Processing Record 16 of Set 8 | blagoyevo
# Processing Record 17 of Set 8 | moron
# Processing Record 18 of Set 8 | new port richey
# Processing Record 19 of Set 8 | labuhan
# Processing Record 20 of Set 8 | kibondo
# Processing Record 21 of Set 8 | longyearbyen
# Processing Record 22 of Set 8 | kavieng
# Processing Record 23 of Set 8 | vilhena
# Processing Record 24 of Set 8 | tungor
# Processing Record 25 of Set 8 | abu kamal
# Processing Record 26 of Set 8 | san ramon de la nueva oran
# Processing Record 27 of Set 8 | ritchie
# Processing Record 28 of Set 8 | katete
# Processing Record 29 of Set 8 | kapuskasing
# Processing Record 30 of Set 8 | tual
# Processing Record 31 of Set 8 | portland
# Processing Record 32 of Set 8 | talara
# Processing Record 33 of Set 8 | ponta delgada
# Processing Record 34 of Set 8 | salina cruz
# Processing Record 35 of Set 8 | hervey bay
# Processing Record 36 of Set 8 | san jose el alto
# Processing Record 37 of Set 8 | victor harbor
# Processing Record 38 of Set 8 | vestmannaeyjar
# Processing Record 39 of Set 8 | kyshtovka
# Processing Record 40 of Set 8 | mackenzie
# Processing Record 41 of Set 8 | zlobin
# Processing Record 42 of Set 8 | batagay-alyta
# Processing Record 43 of Set 8 | ransang
# Processing Record 44 of Set 8 | namatanai
# Processing Record 45 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 8 | udachnyy
# Processing Record 47 of Set 8 | zakamensk
# Processing Record 48 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 8 | moose factory
# Processing Record 50 of Set 8 | san patricio
# Processing Record 1 of Set 9 | itarema
# Processing Record 2 of Set 9 | thinadhoo
# Processing Record 3 of Set 9 | bairiki
# Processing Record 4 of Set 9 | hai duong
# Processing Record 5 of Set 9 | khandyga
# Processing Record 6 of Set 9 | deer lake
# Processing Record 7 of Set 9 | strezhevoy
# Processing Record 8 of Set 9 | ramsar
# Processing Record 9 of Set 9 | lavrentiya
# Processing Record 10 of Set 9 | vila franca do campo
# Processing Record 11 of Set 9 | victoria
# Processing Record 12 of Set 9 | neuquen
# Processing Record 13 of Set 9 | ulkan
# Processing Record 14 of Set 9 | arlit
# Processing Record 15 of Set 9 | houston
# Processing Record 16 of Set 9 | rembang
# Processing Record 17 of Set 9 | rio gallegos
# Processing Record 18 of Set 9 | leshukonskoye
# Processing Record 19 of Set 9 | plettenberg bay
# Processing Record 20 of Set 9 | ewa beach
# Processing Record 21 of Set 9 | saint-paul
# Processing Record 22 of Set 9 | kashi
# Processing Record 23 of Set 9 | ulan-ude
# Processing Record 24 of Set 9 | boysun
# Processing Record 25 of Set 9 | barahona
# Processing Record 26 of Set 9 | constantine
# Processing Record 27 of Set 9 | oparino
# Processing Record 28 of Set 9 | tavatuy
# Processing Record 29 of Set 9 | yantal
# Processing Record 30 of Set 9 | coquimbo
# Processing Record 31 of Set 9 | merauke
# Processing Record 32 of Set 9 | kholmogory
# Processing Record 33 of Set 9 | providencia
# Processing Record 34 of Set 9 | taybad
# Processing Record 35 of Set 9 | kabwe
# Processing Record 36 of Set 9 | saint-louis
# Processing Record 37 of Set 9 | khuzhir
# Processing Record 38 of Set 9 | tazmalt
# Processing Record 39 of Set 9 | kaeo
# Processing Record 40 of Set 9 | morbegno
# Processing Record 41 of Set 9 | lagoa
# Processing Record 42 of Set 9 | pevek
# Processing Record 43 of Set 9 | grindavik
# Processing Record 44 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 45 of Set 9 | gornopravdinsk
# Processing Record 46 of Set 9 | boa vista
# Processing Record 47 of Set 9 | folldal
# Processing Record 48 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 9 | bow island
# Processing Record 50 of Set 9 | pangnirtung
# Processing Record 1 of Set 10 | schwabisch hall
# Processing Record 2 of Set 10 | sungaipenuh
# Processing Record 3 of Set 10 | altus
# Processing Record 4 of Set 10 | serebryansk
# Processing Record 5 of Set 10 | kamenka
# Processing Record 6 of Set 10 | kieta
# Processing Record 7 of Set 10 | waipawa
# Processing Record 8 of Set 10 | farah
# Processing Record 9 of Set 10 | baruun-urt
# Processing Record 10 of Set 10 | nome
# Processing Record 11 of Set 10 | korla
# Processing Record 12 of Set 10 | sao joao da barra
# Processing Record 13 of Set 10 | raudeberg
# Processing Record 14 of Set 10 | tokat
# Processing Record 15 of Set 10 | boralday
# Processing Record 16 of Set 10 | shingu
# Processing Record 17 of Set 10 | la maddalena
# Processing Record 18 of Set 10 | hanzhong
# Processing Record 19 of Set 10 | grande prairie
# Processing Record 20 of Set 10 | namibe
# Processing Record 21 of Set 10 | beloye
# Processing Record 22 of Set 10 | langfang
# Processing Record 23 of Set 10 | mocuba
# Processing Record 24 of Set 10 | yima
# Processing Record 25 of Set 10 | nalut
# Processing Record 26 of Set 10 | vila velha
# Processing Record 27 of Set 10 | port blair
# Processing Record 28 of Set 10 | atambua
# Processing Record 29 of Set 10 | ola
# Processing Record 30 of Set 10 | beatrice
# Processing Record 31 of Set 10 | galeana
# Processing Record 32 of Set 10 | coos bay
# Processing Record 33 of Set 10 | urengoy
# Processing Record 34 of Set 10 | torbay
# Processing Record 35 of Set 10 | tokzar
# City not found. Skipping...
# Processing Record 36 of Set 10 | garowe
# Processing Record 37 of Set 10 | kuah
# Processing Record 38 of Set 10 | touros
# Processing Record 39 of Set 10 | japura
# Processing Record 40 of Set 10 | methoni
# Processing Record 41 of Set 10 | hoa binh
# Processing Record 42 of Set 10 | la ronge
# Processing Record 43 of Set 10 | guiglo
# Processing Record 44 of Set 10 | evensk
# Processing Record 45 of Set 10 | tazovskiy
# Processing Record 46 of Set 10 | shaunavon
# Processing Record 47 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 48 of Set 10 | college
# Processing Record 49 of Set 10 | havoysund
# Processing Record 50 of Set 10 | belle glade
# Processing Record 1 of Set 11 | manama
# Processing Record 2 of Set 11 | faya
# Processing Record 3 of Set 11 | vagamo
# Processing Record 4 of Set 11 | santa cruz
# Processing Record 5 of Set 11 | izmayil
# Processing Record 6 of Set 11 | tateyama
# Processing Record 7 of Set 11 | ongandjera
# Processing Record 8 of Set 11 | bowen
# Processing Record 9 of Set 11 | yerbogachen
# Processing Record 10 of Set 11 | kampene
# Processing Record 11 of Set 11 | luderitz
# Processing Record 12 of Set 11 | mayo
# Processing Record 13 of Set 11 | kaseda
# Processing Record 14 of Set 11 | hoquiam
# Processing Record 15 of Set 11 | plock
# Processing Record 16 of Set 11 | sabla
# Processing Record 17 of Set 11 | vicksburg
# Processing Record 18 of Set 11 | aberlour
# City not found. Skipping...
# Processing Record 19 of Set 11 | buin
# Processing Record 20 of Set 11 | kloulklubed
# Processing Record 21 of Set 11 | harkany
# Processing Record 22 of Set 11 | montague
# Processing Record 23 of Set 11 | buraydah
# Processing Record 24 of Set 11 | abbeville
# Processing Record 25 of Set 11 | mahon
# Processing Record 26 of Set 11 | cacoal
# Processing Record 27 of Set 11 | northam
# Processing Record 28 of Set 11 | albion
# Processing Record 29 of Set 11 | bathsheba
# Processing Record 30 of Set 11 | atar
# Processing Record 31 of Set 11 | bandiagara
# Processing Record 32 of Set 11 | kaiyuan
# Processing Record 33 of Set 11 | curitibanos
# Processing Record 34 of Set 11 | umm ruwabah
# City not found. Skipping...
# Processing Record 35 of Set 11 | clyde river
# Processing Record 36 of Set 11 | san vicente
# Processing Record 37 of Set 11 | lata
# Processing Record 38 of Set 11 | acarau
# Processing Record 39 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 11 | dali
# Processing Record 41 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 42 of Set 11 | hay river
# Processing Record 43 of Set 11 | awjilah
# Processing Record 44 of Set 11 | porto san giorgio
# Processing Record 45 of Set 11 | laguna
# Processing Record 46 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 47 of Set 11 | simi
# Processing Record 48 of Set 11 | pingyi
# Processing Record 49 of Set 11 | hasaki
# Processing Record 50 of Set 11 | halmstad
# Processing Record 1 of Set 12 | birjand
# Processing Record 2 of Set 12 | kimbe
# Processing Record 3 of Set 12 | panaba
# Processing Record 4 of Set 12 | makakilo city
# Processing Record 5 of Set 12 | hayden
# Processing Record 6 of Set 12 | surt
# Processing Record 7 of Set 12 | wilmington
# Processing Record 8 of Set 12 | marawi
# Processing Record 9 of Set 12 | roanoke rapids
# Processing Record 10 of Set 12 | moerai
# Processing Record 11 of Set 12 | penzance
# Processing Record 12 of Set 12 | inirida
# Processing Record 13 of Set 12 | kenora
# Processing Record 14 of Set 12 | nizwa
# Processing Record 15 of Set 12 | fuyu
# Processing Record 16 of Set 12 | bethel
# Processing Record 17 of Set 12 | inuvik
# Processing Record 18 of Set 12 | male
# Processing Record 19 of Set 12 | tortoli
# Processing Record 20 of Set 12 | port macquarie
# Processing Record 21 of Set 12 | palia kalan
# Processing Record 22 of Set 12 | mubende
# Processing Record 23 of Set 12 | vicuna
# Processing Record 24 of Set 12 | powell
# Processing Record 25 of Set 12 | lompoc
# Processing Record 26 of Set 12 | jiayuguan
# Processing Record 27 of Set 12 | alice springs
# Processing Record 28 of Set 12 | belica
# Processing Record 29 of Set 12 | esmeraldas
# Processing Record 30 of Set 12 | cayenne
# Processing Record 31 of Set 12 | pontivy
# Processing Record 32 of Set 12 | yaan
# Processing Record 33 of Set 12 | viedma
# Processing Record 34 of Set 12 | cabuyaro
# Processing Record 35 of Set 12 | qasigiannguit
# Processing Record 36 of Set 12 | zalantun
# Processing Record 37 of Set 12 | esperance
# Processing Record 38 of Set 12 | zhuhai
# Processing Record 39 of Set 12 | campbell river
# Processing Record 40 of Set 12 | lyubim
# Processing Record 41 of Set 12 | yumen
# Processing Record 42 of Set 12 | mandalgovi
# Processing Record 43 of Set 12 | onojo
# Processing Record 44 of Set 12 | matay
# Processing Record 45 of Set 12 | porto walter
# Processing Record 46 of Set 12 | mount isa
# Processing Record 47 of Set 12 | santander
# Processing Record 48 of Set 12 | mount gambier
# Processing Record 49 of Set 12 | bud
# Processing Record 50 of Set 12 | akyab
# Processing Record 1 of Set 13 | sadri
# Processing Record 2 of Set 13 | san martin
# Processing Record 3 of Set 13 | acuna
# City not found. Skipping...
# Processing Record 4 of Set 13 | borama
# City not found. Skipping...
# Processing Record 5 of Set 13 | krasnoye
# Processing Record 6 of Set 13 | chanute
# Processing Record 7 of Set 13 | samdari
# Processing Record 8 of Set 13 | emba
# Processing Record 9 of Set 13 | egvekinot
# Processing Record 10 of Set 13 | solnechnyy
# Processing Record 11 of Set 13 | aklavik
# Processing Record 12 of Set 13 | ayr
# Processing Record 13 of Set 13 | san luis
# Processing Record 14 of Set 13 | beloha
# Processing Record 15 of Set 13 | qaqortoq
# Processing Record 16 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 17 of Set 13 | wamba
# Processing Record 18 of Set 13 | atikokan
# Processing Record 19 of Set 13 | gengenbach
# Processing Record 20 of Set 13 | salalah
# Processing Record 21 of Set 13 | moba
# Processing Record 22 of Set 13 | am timan
# Processing Record 23 of Set 13 | osorno
# Processing Record 24 of Set 13 | rzhaksa
# Processing Record 25 of Set 13 | sao gabriel da cachoeira
# Processing Record 26 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 27 of Set 13 | aljezur
# Processing Record 28 of Set 13 | russell
# Processing Record 29 of Set 13 | ketchikan
# Processing Record 30 of Set 13 | tomatlan
# Processing Record 31 of Set 13 | makung
# City not found. Skipping...
# Processing Record 32 of Set 13 | dzerzhinsk
# Processing Record 33 of Set 13 | yenagoa
# Processing Record 34 of Set 13 | zaplavnoye
# Processing Record 35 of Set 13 | sioux city
# Processing Record 36 of Set 13 | luba
# Processing Record 37 of Set 13 | san carlos de bariloche
# Processing Record 38 of Set 13 | eureka
# Processing Record 39 of Set 13 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 40 of Set 13 | wanaka
# Processing Record 41 of Set 13 | tefe
# Processing Record 42 of Set 13 | puerto del rosario
# Processing Record 43 of Set 13 | gizo
# Processing Record 44 of Set 13 | akkermanovka
# Processing Record 45 of Set 13 | aksarka
# Processing Record 46 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 13 | sikeston
# Processing Record 48 of Set 13 | coroico
# Processing Record 49 of Set 13 | coro
# Processing Record 50 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 14 | njombe
# Processing Record 2 of Set 14 | lhuntshi
# City not found. Skipping...
# Processing Record 3 of Set 14 | sioux lookout
# Processing Record 4 of Set 14 | bosaso
# Processing Record 5 of Set 14 | ugoofaaru
# Processing Record 6 of Set 14 | pisco
# Processing Record 7 of Set 14 | brazzaville
# Processing Record 8 of Set 14 | hualmay
# Processing Record 9 of Set 14 | machiques
# Processing Record 10 of Set 14 | saint-michel-des-saints
# Processing Record 11 of Set 14 | lardos
# Processing Record 12 of Set 14 | jian
# Processing Record 13 of Set 14 | novikovo
# Processing Record 14 of Set 14 | morondava
# Processing Record 15 of Set 14 | kushiro
# Processing Record 16 of Set 14 | inyonga
# Processing Record 17 of Set 14 | dapaong
# Processing Record 18 of Set 14 | kudahuvadhoo
# Processing Record 19 of Set 14 | emerald
# Processing Record 20 of Set 14 | kailua
# Processing Record 21 of Set 14 | hami
# Processing Record 22 of Set 14 | bukowno
# Processing Record 23 of Set 14 | rio branco
# Processing Record 24 of Set 14 | zalaegerszeg
# Processing Record 25 of Set 14 | changde
# Processing Record 26 of Set 14 | nemuro
# Processing Record 27 of Set 14 | basco
# Processing Record 28 of Set 14 | zeerust
# Processing Record 29 of Set 14 | nantucket
# Processing Record 30 of Set 14 | peniche
# Processing Record 31 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 14 | livingstone
# Processing Record 34 of Set 14 | beboto
# Processing Record 35 of Set 14 | westport
# Processing Record 36 of Set 14 | vacaria
# Processing Record 37 of Set 14 | mizdah
# Processing Record 38 of Set 14 | nishihara
# Processing Record 39 of Set 14 | odweyne
# Processing Record 40 of Set 14 | praia
# Processing Record 41 of Set 14 | mahibadhoo
# Processing Record 42 of Set 14 | beian
# Processing Record 43 of Set 14 | sao joao batista
# Processing Record 44 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 14 | barbastro
# Processing Record 46 of Set 14 | bastia
# Processing Record 47 of Set 14 | ereymentau
# Processing Record 48 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 14 | sisimiut
# Processing Record 50 of Set 14 | ouesso
# Processing Record 1 of Set 15 | namuac
# Processing Record 2 of Set 15 | sokoni
# Processing Record 3 of Set 15 | sur
# Processing Record 4 of Set 15 | tres arroyos
# Processing Record 5 of Set 15 | altay
# Processing Record 6 of Set 15 | vuktyl
# Processing Record 7 of Set 15 | north bend
# Processing Record 8 of Set 15 | tiznit
# Processing Record 9 of Set 15 | ebebiyin
# Processing Record 10 of Set 15 | meulaboh
# Processing Record 11 of Set 15 | gull lake
# Processing Record 12 of Set 15 | erenhot
# Processing Record 13 of Set 15 | labuan
# Processing Record 14 of Set 15 | vastervik
# City not found. Skipping...
# Processing Record 15 of Set 15 | champerico
# Processing Record 16 of Set 15 | chimbote
# Processing Record 17 of Set 15 | yongan
# Processing Record 18 of Set 15 | akcakoca
# Processing Record 19 of Set 15 | zelenogradsk
# Processing Record 20 of Set 15 | port-gentil
# Processing Record 21 of Set 15 | rampur
# Processing Record 22 of Set 15 | maun
# Processing Record 23 of Set 15 | mtambile
# Processing Record 24 of Set 15 | vysokogornyy
# Processing Record 25 of Set 15 | aleppo
# Processing Record 26 of Set 15 | wajir
# Processing Record 27 of Set 15 | komsomolskiy
# Processing Record 28 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 15 | ossora
# Processing Record 30 of Set 15 | berehove
# Processing Record 31 of Set 15 | brae
# Processing Record 32 of Set 15 | danville
# Processing Record 33 of Set 15 | impfondo
# Processing Record 34 of Set 15 | seaford
# Processing Record 35 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 36 of Set 15 | port shepstone
# Processing Record 37 of Set 15 | sao felix do xingu
# Processing Record 38 of Set 15 | mecca
# Processing Record 39 of Set 15 | aranos
# Processing Record 40 of Set 15 | ocampo
# Processing Record 41 of Set 15 | kadnikov
# Processing Record 42 of Set 15 | myitkyina
# Processing Record 43 of Set 15 | alta
# Processing Record 44 of Set 15 | ribeira brava
# Processing Record 45 of Set 15 | khani
# Processing Record 46 of Set 15 | ternate
# Processing Record 47 of Set 15 | luancheng
# Processing Record 48 of Set 15 | poum
# Processing Record 49 of Set 15 | santa lucia
# Processing Record 50 of Set 15 | roma
# Processing Record 1 of Set 16 | ojinaga
# Processing Record 2 of Set 16 | burla
# Processing Record 3 of Set 16 | wolmaranstad
# City not found. Skipping...
# Processing Record 4 of Set 16 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 16 | chitral
# Processing Record 6 of Set 16 | anif
# Processing Record 7 of Set 16 | tutoia
# Processing Record 8 of Set 16 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 16 | nevelsk
# Processing Record 10 of Set 16 | kupang
# Processing Record 11 of Set 16 | luena
# Processing Record 12 of Set 16 | olean
# Processing Record 13 of Set 16 | mizan teferi
# Processing Record 14 of Set 16 | new waterford
# Processing Record 15 of Set 16 | lubao
# Processing Record 16 of Set 16 | kadykchan
# City not found. Skipping...
# Processing Record 17 of Set 16 | olinda
# Processing Record 18 of Set 16 | tacuarembo
# Processing Record 19 of Set 16 | khash
# Processing Record 20 of Set 16 | port augusta
# Processing Record 21 of Set 16 | karauzyak
# City not found. Skipping...
# Processing Record 22 of Set 16 | lixourion
# Processing Record 23 of Set 16 | vila
# Processing Record 24 of Set 16 | phangnga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather
# Out:
# {'coord': {'lon': 98.5298, 'lat': 8.4509},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 78.22,
#   'feels_like': 80.17,
#   'temp_min': 75.2,
#   'temp_max': 82,
#   'pressure': 1010,
#   'humidity': 94},
#  'visibility': 10000,
#  'wind': {'speed': 1.14, 'deg': 0},
#  'clouds': {'all': 75},
#  'dt': 1618880048,
#  'sys': {'type': 1,
#   'id': 9278,
#   'country': 'TH',
#   'sunrise': 1618874056,
#   'sunset': 1618918498},
#  'timezone': 25200,
#  'id': 1151464,
#  'name': 'Phang Nga',
#  'cod': 200}

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0  Arraial Do Cabo -22.9661  -42.0278    scattered clouds     77.00        73
# 1    Ordzhonikidze  52.4411   61.7408           clear sky     42.19        30
# 2            Kapaa  22.0752 -159.3190           clear sky     69.80        94
# 3     Punta Arenas -53.1500  -70.9167          few clouds     42.80        75
# 4        Zhanaozen  43.3000   52.8000     overcast clouds     80.56        21
# 5            Vaini -21.2000 -175.2000    scattered clouds     73.40        88
# 6    San Cristobal   7.7669  -72.2250          few clouds     87.80        33
# 7          Fortuna  40.5982 -124.1573     overcast clouds     50.00       100
# 8      Santa Comba  43.0331   -8.8093    scattered clouds     61.00        63
# 9   Ciudad Bolivar   8.1222  -63.5497          few clouds     82.22        56
#
#    Cloudiness  Wind Speed Country                 Date
# 0          40       28.77      BR  2021-04-20 13:14:27
# 1           0        9.22      KZ  2021-04-20 13:14:27
# 2           1        5.75      US  2021-04-20 13:14:28
# 3          20       13.80      CL  2021-04-20 13:14:28
# 4         100       10.76      KZ  2021-04-20 13:14:28
# 5          40        3.44      TO  2021-04-20 13:14:29
# 6          20       23.02      VE  2021-04-20 13:14:29
# 7          90       14.97      US  2021-04-20 13:12:51
# 8          39        8.99      ES  2021-04-20 13:14:29
# 9          17       13.47      VE  2021-04-20 13:14:29

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
